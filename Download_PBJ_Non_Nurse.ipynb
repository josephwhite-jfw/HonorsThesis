# %%
import os
import requests

# Define target directory
target_dir = r"C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw"

# Check it exists
os.makedirs(target_dir, exist_ok=True)

# CMS Data Non-Nurse Staffing Levels API endpoint for the data catalog
api_url = "https://data.cms.gov/data.json"

# Fetch metadata
response = requests.get(api_url)
if response.status_code != 200:
    raise Exception(f"Failed to fetch data from CMS API. Status code: {response.status_code}")

data = response.json()

# Find the PBJ Daily Non-Nurse Staffing dataset
pbj_dataset = None
for dataset in data['dataset']:
    if dataset['title'] == "Payroll Based Journal Daily Non-Nurse Staffing":
        pbj_dataset = dataset
        break

if not pbj_dataset:
    raise Exception("PBJ Daily Non-Nurse Staffing dataset not found in the CMS data catalog.")

# Iterate through each version of the dataset
for distribution in pbj_dataset.get('distribution', []):
    if distribution.get('mediaType') == "text/csv":
        download_url = distribution.get('downloadURL')
        temporal = distribution.get('temporal', 'latest')
        filename = f"PBJ_Daily_Non_Nurse_Staffing_{temporal.replace('/', '_')}.csv"
        file_path = os.path.join(target_dir, filename)

        # Download and save the CSV file
        print(f"Downloading data for period: {temporal}...")
        csv_response = requests.get(download_url)
        if csv_response.status_code == 200:
            with open(file_path, 'wb') as f:
                f.write(csv_response.content)
            print(f"Saved to {file_path}")
        else:
            print(f"Failed to download data for period: {temporal}. Status code: {csv_response.status_code}")
# Out:
# Downloading data for period: 2024-10-01/2024-12-31...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2024-10-01_2024-12-31.csv
# Downloading data for period: 2024-07-01/2024-09-30...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2024-07-01_2024-09-30.csv
# Downloading data for period: 2024-04-01/2024-06-30...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2024-04-01_2024-06-30.csv
# Downloading data for period: 2024-01-01/2024-03-31...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2024-01-01_2024-03-31.csv
# Downloading data for period: 2023-10-01/2023-12-31...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2023-10-01_2023-12-31.csv
# Downloading data for period: 2023-07-01/2023-09-30...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2023-07-01_2023-09-30.csv
# Downloading data for period: 2023-04-01/2023-06-30...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2023-04-01_2023-06-30.csv
# Downloading data for period: 2023-01-01/2023-03-31...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2023-01-01_2023-03-31.csv
# Downloading data for period: 2022-10-01/2022-12-31...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2022-10-01_2022-12-31.csv
# Downloading data for period: 2022-07-01/2022-09-30...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2022-07-01_2022-09-30.csv
# Downloading data for period: 2022-04-01/2022-06-30...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2022-04-01_2022-06-30.csv
# Downloading data for period: 2022-01-01/2022-03-31...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2022-01-01_2022-03-31.csv
# Downloading data for period: 2021-10-01/2021-12-31...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2021-10-01_2021-12-31.csv
# Downloading data for period: 2021-07-01/2021-09-30...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2021-07-01_2021-09-30.csv
# Downloading data for period: 2021-04-01/2021-06-30...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2021-04-01_2021-06-30.csv
# Downloading data for period: 2021-01-01/2021-03-31...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2021-01-01_2021-03-31.csv
# Downloading data for period: 2020-10-01/2020-12-31...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2020-10-01_2020-12-31.csv
# Downloading data for period: 2020-07-01/2020-09-30...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2020-07-01_2020-09-30.csv
# Downloading data for period: 2020-04-01/2020-06-30...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2020-04-01_2020-06-30.csv
# Downloading data for period: 2020-01-01/2020-03-31...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2020-01-01_2020-03-31.csv
# Downloading data for period: 2019-10-01/2019-12-31...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2019-10-01_2019-12-31.csv
# Downloading data for period: 2019-07-01/2019-09-30...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2019-07-01_2019-09-30.csv
# Downloading data for period: 2019-04-01/2019-06-30...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2019-04-01_2019-06-30.csv
# Downloading data for period: 2019-01-01/2019-03-31...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2019-01-01_2019-03-31.csv
# Downloading data for period: 2018-10-01/2018-12-31...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2018-10-01_2018-12-31.csv
# Downloading data for period: 2018-07-01/2018-09-30...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2018-07-01_2018-09-30.csv
# Downloading data for period: 2018-04-01/2018-06-30...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2018-04-01_2018-06-30.csv
# Downloading data for period: 2018-01-01/2018-03-31...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2018-01-01_2018-03-31.csv
# Downloading data for period: 2017-10-01/2017-12-31...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2017-10-01_2017-12-31.csv
# Downloading data for period: 2017-07-01/2017-09-30...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2017-07-01_2017-09-30.csv
# Downloading data for period: 2017-04-01/2017-06-30...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2017-04-01_2017-06-30.csv
# Downloading data for period: 2017-01-01/2017-03-31...
# Saved to C:\Users\Owner\OneDrive\Documents\Honors_Thesis\data\data-raw\PBJ_Daily_Non_Nurse_Staffing_2017-01-01_2017-03-31.csv
